# %%
from pathlib import Path
import sys
project_root = Path.cwd().resolve().parents[0] if Path.cwd().name=="notebooks" else Path.cwd().resolve()
sys.path.append(str(project_root / "src"))
from productize import run_full_training_and_save
run_full_training_and_save(project_root)
# Out:
# {'train': {'rmse': 0.02571943359176017,
#   'mae': 0.019411103151888567,
#   'r2': 0.004281230608835673},
#  'test': {'rmse': 0.027239850657238718,
#   'mae': 0.018060533427832683,
#   'r2': 0.004032012585594269},
#  'n_train': 987,
#  'n_test': 247}

# %%
from pathlib import Path
import sys
project_root = Path.cwd().resolve().parents[0] if Path.cwd().name=="notebooks" else Path.cwd().resolve()
sys.path.append(str(project_root / "src"))
from productize import load_artifacts, vector_from_payload

pipe, defaults, features = load_artifacts(project_root)

# minimal example payload; missing fields will use training medians
payload = {"ret": 0.001, "ret_lag1": -0.002}
x = vector_from_payload(payload, features, defaults)
pred = float(pipe.predict(x)[0])
pred
# Out:
# C:\Users\melin\OneDrive\Desktop\nyu\python\bootcamp_panagiotis_housos\env\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 0.001074422021017275
